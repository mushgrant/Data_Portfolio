# %% [markdown]
# Importation of libraries and dataset

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('mpg_dataset (2).csv')
data.head()
# Out:
#   manufacturer model  displacement  year  cylinder transmission  drive  \
# 0         audi    a4           1.8  1999         4     auto(l5)  front
# 1         audi    a4           1.8  1999         4   manual(m5)  front
# 2         audi    a4           2.0  2008         4   manual(m6)  front
# 3         audi    a4           2.0  2008         4     auto(av)  front
# 4         audi    a4           2.8  1999         6     auto(l5)  front
#
#    city_mpg  highway_mpg fuel_type    class
# 0        18           29         p  compact
# 1        21           29         p  compact
# 2        20           31         p  compact
# 3        21           30         p  compact
# 4        16           26         p  compact

# %% [markdown]
# What is the size and structure of our dataset?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displacement    234 non-null float64
# year            234 non-null int64
# cylinder        234 non-null int64
# transmission    234 non-null object
# drive           234 non-null object
# city_mpg        234 non-null int64
# highway_mpg     234 non-null int64
# fuel_type       234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %% [markdown]
# Dataset is made up of 3 dtypes with what looks like no null values. Let's make sure.

# %%
data.isnull().sum()
# Out:
# manufacturer    0
# model           0
# displacement    0
# year            0
# cylinder        0
# transmission    0
# drive           0
# city_mpg        0
# highway_mpg     0
# fuel_type       0
# class           0
# dtype: int64

# %% [markdown]
# We can get a closer look at the distribution of the data by seperating it by manufacturer

# %%
manu = set(data['manufacturer'])

# %%
manu
# Out:
# {'audi',
#  'chevrolet',
#  'dodge',
#  'ford',
#  'honda',
#  'hyundai',
#  'jeep',
#  'land rover',
#  'lincoln',
#  'mercury',
#  'nissan',
#  'pontiac',
#  'subaru',
#  'toyota',
#  'volkswagen'}

# %%
for m in manu:
    print'----------------',m.upper(),'---------------------'
    print(data[data['manufacturer'] == m].describe())
    print('\n')
# Out:
# ---------------- DODGE ---------------------
#        displacement         year   cylinder   city_mpg  highway_mpg
# count     37.000000    37.000000  37.000000  37.000000    37.000000
# mean       4.378378  2004.108108   7.081081  13.135135    17.945946
# std        0.867991     4.520225   1.115008   2.485091     3.574182
# min        2.400000  1999.000000   4.000000   9.000000    12.000000
# 25%        3.800000  1999.000000   6.000000  11.000000    16.000000
# 50%        4.700000  2008.000000   8.000000  13.000000    17.000000
# 75%        4.700000  2008.000000   8.000000  15.000000    21.000000
# max        5.900000  2008.000000   8.000000  18.000000    24.000000
#
#
# ---------------- MERCURY ---------------------
#        displacement         year  cylinder  city_mpg  highway_mpg
# count      4.000000     4.000000  4.000000      4.00     4.000000
# mean       4.400000  2003.500000  7.000000     13.25    18.000000
# std        0.489898     5.196152  1.154701      0.50     1.154701
# min        4.000000  1999.000000  6.000000     13.00    17.000000
# 25%        4.000000  1999.000000  6.000000     13.00    17.000000
# 50%        4.300000  2003.500000  7.000000     13.00    18.000000
# 75%        4.700000  2008.000000  8.000000     13.25    19.000000
# max        5.000000  2008.000000  8.000000     14.00    19.000000
#
#
# ---------------- LINCOLN ---------------------
#        displacement         year  cylinder   city_mpg  highway_mpg
# count  3.000000e+00     3.000000       3.0   3.000000          3.0
# mean   5.400000e+00  2002.000000       8.0  11.333333         17.0
# std    1.087792e-15     5.196152       0.0   0.577350          1.0
# min    5.400000e+00  1999.000000       8.0  11.000000         16.0
# 25%    5.400000e+00  1999.000000       8.0  11.000000         16.5
# 50%    5.400000e+00  1999.000000       8.0  11.000000         17.0
# 75%    5.400000e+00  2003.500000       8.0  11.500000         17.5
# max    5.400000e+00  2008.000000       8.0  12.000000         18.0
#
#
# ---------------- PONTIAC ---------------------
#        displacement         year  cylinder  city_mpg  highway_mpg
# count      5.000000     5.000000  5.000000       5.0     5.000000
# mean       3.960000  2002.600000  6.400000      17.0    26.400000
# std        0.808084     4.929503  0.894427       1.0     1.140175
# min        3.100000  1999.000000  6.000000      16.0    25.000000
# 25%        3.800000  1999.000000  6.000000      16.0    26.000000
# 50%        3.800000  1999.000000  6.000000      17.0    26.000000
# 75%        3.800000  2008.000000  6.000000      18.0    27.000000
# max        5.300000  2008.000000  8.000000      18.0    28.000000
#
#
# ---------------- JEEP ---------------------
#        displacement        year  cylinder   city_mpg  highway_mpg
# count      8.000000     8.00000  8.000000   8.000000     8.000000
# mean       4.575000  2005.75000  7.250000  13.500000    17.625000
# std        1.015241     4.16619  1.035098   2.507133     3.248626
# min        3.000000  1999.00000  6.000000   9.000000    12.000000
# 25%        3.925000  2005.75000  6.000000  12.500000    16.250000
# 50%        4.700000  2008.00000  8.000000  14.000000    18.500000
# 75%        4.950000  2008.00000  8.000000  15.000000    19.250000
# max        6.100000  2008.00000  8.000000  17.000000    22.000000
#
#
# ---------------- CHEVROLET ---------------------
#        displacement         year   cylinder   city_mpg  highway_mpg
# count     19.000000    19.000000  19.000000  19.000000    19.000000
# mean       5.063158  2004.684211   7.263158  15.000000    21.894737
# std        1.370406     4.460352   1.367971   2.924988     5.108759
# min        2.400000  1999.000000   4.000000  11.000000    14.000000
# 25%        4.450000  1999.000000   7.000000  13.500000    17.000000
# 50%        5.300000  2008.000000   8.000000  15.000000    23.000000
# 75%        5.850000  2008.000000   8.000000  16.500000    26.000000
# max        7.000000  2008.000000   8.000000  22.000000    30.000000
#
#
# ---------------- NISSAN ---------------------
#        displacement         year   cylinder   city_mpg  highway_mpg
# count     13.000000    13.000000  13.000000  13.000000    13.000000
# mean       3.269231  2003.846154   5.538462  18.076923    24.615385
# std        0.864470     4.669871   1.198289   3.426892     5.091471
# min        2.400000  1999.000000   4.000000  12.000000    17.000000
# 25%        2.500000  1999.000000   4.000000  15.000000    20.000000
# 50%        3.300000  2008.000000   6.000000  19.000000    26.000000
# 75%        3.500000  2008.000000   6.000000  19.000000    27.000000
# max        5.600000  2008.000000   8.000000  23.000000    32.000000
#
#
# ---------------- HONDA ---------------------
#        displacement         year  cylinder   city_mpg  highway_mpg
# count      9.000000     9.000000       9.0   9.000000     9.000000
# mean       1.711111  2003.000000       4.0  24.444444    32.555556
# std        0.145297     4.743416       0.0   1.943651     2.554952
# min        1.600000  1999.000000       4.0  21.000000    29.000000
# 25%        1.600000  1999.000000       4.0  24.000000    32.000000
# 50%        1.600000  1999.000000       4.0  24.000000    32.000000
# 75%        1.800000  2008.000000       4.0  25.000000    34.000000
# max        2.000000  2008.000000       4.0  28.000000    36.000000
#
#
# ---------------- TOYOTA ---------------------
#        displacement         year   cylinder   city_mpg  highway_mpg
# count     34.000000    34.000000  34.000000  34.000000    34.000000
# mean       2.952941  2002.705882   5.117647  18.529412    24.911765
# std        0.931351     4.495988   1.320347   4.046961     6.166221
# min        1.800000  1999.000000   4.000000  11.000000    15.000000
# 25%        2.250000  1999.000000   4.000000  15.000000    20.000000
# 50%        2.700000  1999.000000   4.000000  18.000000    26.000000
# 75%        3.400000  2008.000000   6.000000  21.000000    29.750000
# max        5.700000  2008.000000   8.000000  28.000000    37.000000
#
#
# ---------------- HYUNDAI ---------------------
#        displacement         year   cylinder   city_mpg  highway_mpg
# count     14.000000    14.000000  14.000000  14.000000    14.000000
# mean       2.428571  2004.142857   4.857143  18.642857    26.857143
# std        0.364646     4.621973   1.027105   1.499084     2.178819
# min        2.000000  1999.000000   4.000000  16.000000    24.000000
# 25%        2.100000  1999.000000   4.000000  18.000000    26.000000
# 50%        2.400000  2008.000000   4.000000  18.500000    26.500000
# 75%        2.650000  2008.000000   6.000000  19.750000    28.000000
# max        3.300000  2008.000000   6.000000  21.000000    31.000000
#
#
# ---------------- FORD ---------------------
#        displacement    year  cylinder   city_mpg  highway_mpg
# count      25.00000    25.0      25.0  25.000000    25.000000
# mean        4.53600  2002.6       7.2  14.000000    19.360000
# std         0.54074     4.5       1.0   1.914854     3.327662
# min         3.80000  1999.0       6.0  11.000000    15.000000
# 25%         4.00000  1999.0       6.0  13.000000    17.000000
# 50%         4.60000  1999.0       8.0  14.000000    18.000000
# 75%         4.60000  2008.0       8.0  15.000000    22.000000
# max         5.40000  2008.0       8.0  18.000000    26.000000
#
#
# ---------------- SUBARU ---------------------
#        displacement         year  cylinder   city_mpg  highway_mpg
# count     14.000000    14.000000      14.0  14.000000    14.000000
# mean       2.457143  2004.142857       4.0  19.285714    25.571429
# std        0.108941     4.621973       0.0   0.913874     1.157868
# min        2.200000  1999.000000       4.0  18.000000    23.000000
# 25%        2.500000  1999.000000       4.0  19.000000    25.000000
# 50%        2.500000  2008.000000       4.0  19.000000    26.000000
# 75%        2.500000  2008.000000       4.0  20.000000    26.000000
# max        2.500000  2008.000000       4.0  21.000000    27.000000
#
#
# ---------------- LAND ROVER ---------------------
#        displacement         year  cylinder  city_mpg  highway_mpg
# count      4.000000     4.000000       4.0   4.00000     4.000000
# mean       4.300000  2003.500000       8.0  11.50000    16.500000
# std        0.258199     5.196152       0.0   0.57735     1.732051
# min        4.000000  1999.000000       8.0  11.00000    15.000000
# 25%        4.150000  1999.000000       8.0  11.00000    15.000000
# 50%        4.300000  2003.500000       8.0  11.50000    16.500000
# 75%        4.450000  2008.000000       8.0  12.00000    18.000000
# max        4.600000  2008.000000       8.0  12.00000    18.000000
#
#
# ---------------- VOLKSWAGEN ---------------------
#        displacement         year   cylinder   city_mpg  highway_mpg
# count     27.000000    27.000000  27.000000  27.000000    27.000000
# mean       2.255556  2002.666667   4.592593  20.925926    29.222222
# std        0.443182     4.506406   0.843949   4.556702     5.315676
# min        1.800000  1999.000000   4.000000  16.000000    23.000000
# 25%        2.000000  1999.000000   4.000000  18.500000    26.000000
# 50%        2.000000  1999.000000   4.000000  21.000000    29.000000
# 75%        2.500000  2008.000000   5.000000  21.000000    29.000000
# max        3.600000  2008.000000   6.000000  35.000000    44.000000
#
#
# ---------------- AUDI ---------------------
#        displacement         year   cylinder   city_mpg  highway_mpg
# count     18.000000    18.000000  18.000000  18.000000    18.000000
# mean       2.544444  2003.500000   5.222222  17.611111    26.444444
# std        0.673203     4.630462   1.215370   1.974511     2.175322
# min        1.800000  1999.000000   4.000000  15.000000    23.000000
# 25%        2.000000  1999.000000   4.000000  16.000000    25.000000
# 50%        2.800000  2003.500000   6.000000  17.500000    26.000000
# 75%        3.025000  2008.000000   6.000000  18.750000    27.750000
# max        4.200000  2008.000000   8.000000  21.000000    31.000000

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="manufacturer", y="highway_mpg", data=data)
plt.title("HIGHWAY_MPG");

# %% [markdown]
# The above graph shows us that honda make the most fuel efficient cars based on highway_mph. The least fuel efficient belongs to the land rover however it is very close to a few other companies.
# city_mpg looks like it should be highly correlated to highway_mpg and thus would provide  similar results. Let's see how correlated they are to each other.

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="manufacturer", y="city_mpg", data=data)
plt.title("CITY_MPG");

# %% [markdown]
# Looks like we get basically the same results. the minimum changed but, they're very close and the sample size from each of those manufacturers was very small.

# %%
plt.scatter(data['city_mpg'], data['highway_mpg'])
plt.xlabel('city_mpg')
plt.ylabel('highway_mpg')

# %% [markdown]
# There is a strong correlation between the two. An increase in fuel efficiency in one category is accompanied by an increase in the other. Let's group them by manufacturer.

# %%
sns.factorplot(data=data, y='highway_mpg', x='city_mpg', col='manufacturer')

# %% [markdown]
# The correlation holds for the most part. lets look and see how it changes when seperated by class

# %%
sns.factorplot(data=data, y='highway_mpg', x='city_mpg', col='class')

# %% [markdown]
# Distribution by class.

# %%
grid = sns.FacetGrid(data, col="manufacturer")
grid.map(sns.distplot,'highway_mpg')

# %%
grid = sns.FacetGrid(data, col="class")
grid.map(sns.distplot,'city_mpg')

# %% [markdown]
# Resemblance of a normal distribution. Another look at the distribution using boxplots

# %%
class_city_mpg = data[['class', 'city_mpg']]

# %%
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='class', y="city_mpg", data=class_city_mpg)
fig.axis(ymin=0, ymax=40);

# %%
class_city_mpg['class'].value_counts()
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: class, dtype: int64

# %% [markdown]
# Look at the distribution when seperated by cylinder

# %%
cylinder_city = data[['cylinder', 'city_mpg']]

# %%
cylinder_city['cylinder'].value_counts()
# Out:
# 4    81
# 6    79
# 8    70
# 5     4
# Name: cylinder, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='cylinder', y="city_mpg", data=cylinder_city)
fig.axis(ymin=0, ymax=40);

# %% [markdown]
# Comparing correlations between columns

# %%
data.corr()
# Out:
#               displacement      year  cylinder  city_mpg  highway_mpg
# displacement      1.000000  0.147843  0.930227 -0.798524    -0.766020
# year              0.147843  1.000000  0.122245 -0.037232     0.002158
# cylinder          0.930227  0.122245  1.000000 -0.805771    -0.761912
# city_mpg         -0.798524 -0.037232 -0.805771  1.000000     0.955916
# highway_mpg      -0.766020  0.002158 -0.761912  0.955916     1.000000

# %%
sns.heatmap(data.corr())

# %% [markdown]
# As expected we see an extremly high positive correlation between city and highway mpg. There is also a strong negative correlation between mpg and cylinder. The multicollinearity show by the above data may cause inaccuracies if we were to go and build a regression model from the data.

# %% [markdown]
# The data above was missing the object variables. We can use dummy variables to get an idea of the correlation of manufacturer and class with both mpgs.

# %%
dummy_df = pd.get_dummies(data, columns=['manufacturer'])

# %%
dummy_df.corr()
# Out:
#                          displacement          year  cylinder  city_mpg  \
# displacement                 1.000000  1.478428e-01  0.930227 -0.798524
# year                         0.147843  1.000000e+00  0.122245 -0.037232
# cylinder                     0.930227  1.222453e-01  1.000000 -0.805771
# city_mpg                    -0.798524 -3.723229e-02 -0.805771  1.000000
# highway_mpg                 -0.766020  2.157643e-03 -0.761912  0.955916
# manufacturer_audi           -0.207651 -4.352385e-18 -0.119676  0.051126
# manufacturer_chevrolet       0.366951  7.823012e-02  0.254050 -0.130126
# manufacturer_dodge           0.304759  5.856471e-02  0.321295 -0.380008
# manufacturer_ford            0.285498 -6.917145e-02  0.281985 -0.232831
# manufacturer_honda          -0.273145 -2.222222e-02 -0.234924  0.357229
# manufacturer_hyundai        -0.204132  3.603750e-02 -0.161851  0.105963
# manufacturer_jeep            0.161001  9.407209e-02  0.159248 -0.148810
# manufacturer_land rover      0.084720 -4.066997e-19  0.173128 -0.166411
# manufacturer_lincoln         0.170447 -3.798686e-02  0.149608 -0.148276
# manufacturer_mercury         0.094949 -2.033498e-18  0.091120 -0.112069
# manufacturer_nissan         -0.038108  1.865659e-02 -0.052852  0.069557
# manufacturer_pontiac         0.055957 -2.955271e-02  0.046965  0.004907
# manufacturer_subaru         -0.198541  3.603750e-02 -0.296312  0.144148
# manufacturer_toyota         -0.165940 -7.276069e-02 -0.197745  0.162177
# manufacturer_volkswagen     -0.340719 -6.688103e-02 -0.291133  0.345859
#
#                          highway_mpg  manufacturer_audi  \
# displacement               -0.766020      -2.076512e-01
# year                        0.002158      -4.352385e-18
# cylinder                   -0.761912      -1.196764e-01
# city_mpg                    0.955916       5.112580e-02
# highway_mpg                 1.000000       1.459564e-01
# manufacturer_audi           0.145956       1.000000e+00
# manufacturer_chevrolet     -0.077318      -8.581574e-02
# manufacturer_dodge         -0.400727      -1.251057e-01
# manufacturer_ford          -0.237492      -9.984038e-02
# manufacturer_honda          0.306817      -5.773503e-02
# manufacturer_hyundai        0.145067      -7.282191e-02
# manufacturer_jeep          -0.184131      -5.431254e-02
# manufacturer_land rover    -0.154032      -3.806935e-02
# manufacturer_lincoln       -0.123517      -3.289758e-02
# manufacturer_mercury       -0.120740      -3.806935e-02
# manufacturer_nissan         0.047970      -7.001400e-02
# manufacturer_pontiac        0.073605      -4.265566e-02
# manufacturer_subaru         0.090482      -7.282191e-02
# manufacturer_toyota         0.102114      -1.190238e-01
# manufacturer_volkswagen     0.351441      -1.042572e-01
#
#                          manufacturer_chevrolet  manufacturer_dodge  \
# displacement                           0.366951            0.304759
# year                                   0.078230            0.058565
# cylinder                               0.254050            0.321295
# city_mpg                              -0.130126           -0.380008
# highway_mpg                           -0.077318           -0.400727
# manufacturer_audi                     -0.085816           -0.125106
# manufacturer_chevrolet                 1.000000           -0.128832
# manufacturer_dodge                    -0.128832            1.000000
# manufacturer_ford                     -0.102815           -0.149887
# manufacturer_honda                    -0.059455           -0.086676
# manufacturer_hyundai                  -0.074991           -0.109325
# manufacturer_jeep                     -0.055930           -0.081538
# manufacturer_land rover               -0.039203           -0.057152
# manufacturer_lincoln                  -0.033878           -0.049388
# manufacturer_mercury                  -0.039203           -0.057152
# manufacturer_nissan                   -0.072100           -0.105110
# manufacturer_pontiac                  -0.043926           -0.064038
# manufacturer_subaru                   -0.074991           -0.109325
# manufacturer_toyota                   -0.122569           -0.178687
# manufacturer_volkswagen               -0.107363           -0.156518
#
#                          manufacturer_ford  manufacturer_honda  \
# displacement                      0.285498           -0.273145
# year                             -0.069171           -0.022222
# cylinder                          0.281985           -0.234924
# city_mpg                         -0.232831            0.357229
# highway_mpg                      -0.237492            0.306817
# manufacturer_audi                -0.099840           -0.057735
# manufacturer_chevrolet           -0.102815           -0.059455
# manufacturer_dodge               -0.149887           -0.086676
# manufacturer_ford                 1.000000           -0.069171
# manufacturer_honda               -0.069171            1.000000
# manufacturer_hyundai             -0.087247           -0.050452
# manufacturer_jeep                -0.065071           -0.037629
# manufacturer_land rover          -0.045610           -0.026375
# manufacturer_lincoln             -0.039414           -0.022792
# manufacturer_mercury             -0.045610           -0.026375
# manufacturer_nissan              -0.083883           -0.048507
# manufacturer_pontiac             -0.051105           -0.029553
# manufacturer_subaru              -0.087247           -0.050452
# manufacturer_toyota              -0.142601           -0.082462
# manufacturer_volkswagen          -0.124909           -0.072232
#
#                          manufacturer_hyundai  manufacturer_jeep  \
# displacement                        -0.204132           0.161001
# year                                 0.036037           0.094072
# cylinder                            -0.161851           0.159248
# city_mpg                             0.105963          -0.148810
# highway_mpg                          0.145067          -0.184131
# manufacturer_audi                   -0.072822          -0.054313
# manufacturer_chevrolet              -0.074991          -0.055930
# manufacturer_dodge                  -0.109325          -0.081538
# manufacturer_ford                   -0.087247          -0.065071
# manufacturer_honda                  -0.050452          -0.037629
# manufacturer_hyundai                 1.000000          -0.047462
# manufacturer_jeep                   -0.047462           1.000000
# manufacturer_land rover             -0.033267          -0.024812
# manufacturer_lincoln                -0.028748          -0.021441
# manufacturer_mercury                -0.033267          -0.024812
# manufacturer_nissan                 -0.061183          -0.045632
# manufacturer_pontiac                -0.037275          -0.027801
# manufacturer_subaru                 -0.063636          -0.047462
# manufacturer_toyota                 -0.104010          -0.077574
# manufacturer_volkswagen             -0.091107          -0.067950
#
#                          manufacturer_land rover  manufacturer_lincoln  \
# displacement                        8.471986e-02              0.170447
# year                               -4.066997e-19             -0.037987
# cylinder                            1.731281e-01              0.149608
# city_mpg                           -1.664109e-01             -0.148276
# highway_mpg                        -1.540318e-01             -0.123517
# manufacturer_audi                  -3.806935e-02             -0.032898
# manufacturer_chevrolet             -3.920339e-02             -0.033878
# manufacturer_dodge                 -5.715232e-02             -0.049388
# manufacturer_ford                  -4.561030e-02             -0.039414
# manufacturer_honda                 -2.637522e-02             -0.022792
# manufacturer_hyundai               -3.326739e-02             -0.028748
# manufacturer_jeep                  -2.481172e-02             -0.021441
# manufacturer_land rover             1.000000e+00             -0.015029
# manufacturer_lincoln               -1.502868e-02              1.000000
# manufacturer_mercury               -1.739130e-02             -0.015029
# manufacturer_nissan                -3.198465e-02             -0.027639
# manufacturer_pontiac               -1.948648e-02             -0.016839
# manufacturer_subaru                -3.326739e-02             -0.028748
# manufacturer_toyota                -5.437391e-02             -0.046987
# manufacturer_volkswagen            -4.762805e-02             -0.041158
#
#                          manufacturer_mercury  manufacturer_nissan  \
# displacement                     9.494919e-02            -0.038108
# year                            -2.033498e-18             0.018657
# cylinder                         9.112005e-02            -0.052852
# city_mpg                        -1.120686e-01             0.069557
# highway_mpg                     -1.207405e-01             0.047970
# manufacturer_audi               -3.806935e-02            -0.070014
# manufacturer_chevrolet          -3.920339e-02            -0.072100
# manufacturer_dodge              -5.715232e-02            -0.105110
# manufacturer_ford               -4.561030e-02            -0.083883
# manufacturer_honda              -2.637522e-02            -0.048507
# manufacturer_hyundai            -3.326739e-02            -0.061183
# manufacturer_jeep               -2.481172e-02            -0.045632
# manufacturer_land rover         -1.739130e-02            -0.031985
# manufacturer_lincoln            -1.502868e-02            -0.027639
# manufacturer_mercury             1.000000e+00            -0.031985
# manufacturer_nissan             -3.198465e-02             1.000000
# manufacturer_pontiac            -1.948648e-02            -0.035838
# manufacturer_subaru             -3.326739e-02            -0.061183
# manufacturer_toyota             -5.437391e-02            -0.100000
# manufacturer_volkswagen         -4.762805e-02            -0.087594
#
#                          manufacturer_pontiac  manufacturer_subaru  \
# displacement                         0.055957            -0.198541
# year                                -0.029553             0.036037
# cylinder                             0.046965            -0.296312
# city_mpg                             0.004907             0.144148
# highway_mpg                          0.073605             0.090482
# manufacturer_audi                   -0.042656            -0.072822
# manufacturer_chevrolet              -0.043926            -0.074991
# manufacturer_dodge                  -0.064038            -0.109325
# manufacturer_ford                   -0.051105            -0.087247
# manufacturer_honda                  -0.029553            -0.050452
# manufacturer_hyundai                -0.037275            -0.063636
# manufacturer_jeep                   -0.027801            -0.047462
# manufacturer_land rover             -0.019486            -0.033267
# manufacturer_lincoln                -0.016839            -0.028748
# manufacturer_mercury                -0.019486            -0.033267
# manufacturer_nissan                 -0.035838            -0.061183
# manufacturer_pontiac                 1.000000            -0.037275
# manufacturer_subaru                 -0.037275             1.000000
# manufacturer_toyota                 -0.060924            -0.104010
# manufacturer_volkswagen             -0.053366            -0.091107
#
#                          manufacturer_toyota  manufacturer_volkswagen
# displacement                       -0.165940                -0.340719
# year                               -0.072761                -0.066881
# cylinder                           -0.197745                -0.291133
# city_mpg                            0.162177                 0.345859
# highway_mpg                         0.102114                 0.351441
# manufacturer_audi                  -0.119024                -0.104257
# manufacturer_chevrolet             -0.122569                -0.107363
# manufacturer_dodge                 -0.178687                -0.156518
# manufacturer_ford                  -0.142601                -0.124909
# manufacturer_honda                 -0.082462                -0.072232
# manufacturer_hyundai               -0.104010                -0.091107
# manufacturer_jeep                  -0.077574                -0.067950
# manufacturer_land rover            -0.054374                -0.047628
# manufacturer_lincoln               -0.046987                -0.041158
# manufacturer_mercury               -0.054374                -0.047628
# manufacturer_nissan                -0.100000                -0.087594
# manufacturer_pontiac               -0.060924                -0.053366
# manufacturer_subaru                -0.104010                -0.091107
# manufacturer_toyota                 1.000000                -0.148909
# manufacturer_volkswagen            -0.148909                 1.000000

# %%
class_dummy = pd.get_dummies(data, columns=['class'])

# %%
class_dummy.corr()
# Out:
#                   displacement      year  cylinder  city_mpg  highway_mpg  \
# displacement          1.000000  0.147843  0.930227 -0.798524    -0.766020
# year                  0.147843  1.000000  0.122245 -0.037232     0.002158
# cylinder              0.930227  0.122245  1.000000 -0.805771    -0.761912
# city_mpg             -0.798524 -0.037232 -0.805771  1.000000     0.955916
# highway_mpg          -0.766020  0.002158 -0.761912  0.955916     1.000000
# class_2seater         0.308114  0.029553  0.193985 -0.050763     0.033816
# class_compact        -0.445752 -0.032000 -0.403149  0.385865     0.409858
# class_midsize        -0.196577  0.011242 -0.163893  0.205894     0.298835
# class_minivan        -0.013935 -0.020191 -0.009766 -0.054430    -0.040239
# class_pickup          0.297447  0.012278  0.287602 -0.368184    -0.447434
# class_subcompact     -0.264080 -0.035947 -0.224366  0.346858     0.331916
# class_suv             0.458562  0.038735  0.402795 -0.474867    -0.536653
#
#                   class_2seater  class_compact  class_midsize  class_minivan  \
# displacement           0.308114      -0.445752      -0.196577      -0.013935
# year                   0.029553      -0.032000       0.011242      -0.020191
# cylinder               0.193985      -0.403149      -0.163893      -0.009766
# city_mpg              -0.050763       0.385865       0.205894      -0.054430
# highway_mpg            0.033816       0.409858       0.298835      -0.040239
# class_2seater          1.000000      -0.074079      -0.068105      -0.032818
# class_compact         -0.074079       1.000000      -0.231069      -0.111345
# class_midsize         -0.068105      -0.231069       1.000000      -0.102366
# class_minivan         -0.032818      -0.111345      -0.102366       1.000000
# class_pickup          -0.059872      -0.203136      -0.186755      -0.089992
# class_subcompact      -0.061969      -0.210250      -0.193295      -0.093143
# class_suv             -0.088715      -0.300995      -0.276723      -0.133345
#
#                   class_pickup  class_subcompact  class_suv
# displacement          0.297447         -0.264080   0.458562
# year                  0.012278         -0.035947   0.038735
# cylinder              0.287602         -0.224366   0.402795
# city_mpg             -0.368184          0.346858  -0.474867
# highway_mpg          -0.447434          0.331916  -0.536653
# class_2seater        -0.059872         -0.061969  -0.088715
# class_compact        -0.203136         -0.210250  -0.300995
# class_midsize        -0.186755         -0.193295  -0.276723
# class_minivan        -0.089992         -0.093143  -0.133345
# class_pickup          1.000000         -0.169929  -0.243271
# class_subcompact     -0.169929          1.000000  -0.251790
# class_suv            -0.243271         -0.251790   1.000000

# %% [markdown]
# class seems to be the better indicator of correlation. Class may be a better predicter of mpg over manufacturer.
